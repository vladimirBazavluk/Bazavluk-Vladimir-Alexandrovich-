# %%
# !apt install postgresql postgresql-contrib &>log
# !service postgresql start
# !sudo -u postgres psql -c "CREATE USER root WITH SUPERUSER"
# set connection
# %reload_ext sql
# %config SqlMagic.feedback=False
# %config SqlMagic.autopandas=True
# %sql postgresql+psycopg2://@/postgres
# Out:
#  * Starting PostgreSQL 14 database server
#    ...done.
# ERROR:  role "root" already exists

# %%
# %sql CREATE TABLE Customer (customer_id INTEGER, first_name VARCHAR(100), last_name VARCHAR(100), gender VARCHAR(6), DOB DATE, job_title VARCHAR(100), job_industry_category VARCHAR(100), wealth_segment VARCHAR(100), deceased_indicator VARCHAR(10), owns_car VARCHAR(100), address VARCHAR(100), postcode VARCHAR(10), state VARCHAR(100), country VARCHAR(100), property_valuation INTEGER);

# %sql COPY Customer FROM '/content/customer.csv' DELIMITER ';' CSV HEADER;
# Out:
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %sql SELECT * FROM Customer;
# Out:
#  * postgresql+psycopg2://@/postgres
#       customer_id      first_name  last_name  gender         dob  \
# 0               1         Laraine  Medendorp       F  1953-10-12
# 1               2             Eli    Bockman    Male  1980-12-16
# 2               3           Arlin     Dearle    Male  1954-01-20
# 3               4          Talbot       None    Male  1961-10-03
# 4               5  Sheila-kathryn     Calton  Female  1977-05-13
# ...           ...             ...        ...     ...         ...
# 3995         3996         Rosalia   Halgarth  Female  1975-08-09
# 3996         3997          Blanch     Nisuis  Female  2001-07-13
# 3997         3998          Sarene    Woolley       U        None
# 3998         3999       Patrizius       None    Male  1973-10-24
# 3999         4000           Kippy    Oldland    Male  1991-11-05
#
#                    job_title job_industry_category     wealth_segment  \
# 0        Executive Secretary                Health      Mass Customer
# ...

# %%
import csv
import pandas as pd


with open('transaction.csv', 'r') as file:
    reader = csv.reader(file, delimiter=';')
    data = list(reader)

for row in data:
    row[10] = row[10].replace(',', '.')
    row[11] = row[11].replace(',', '.')

with open('transaction.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data)
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950          2.25.17        False
# 1                   2           3         3120          5.21.17         True
# 2                   3          37          402         10.16.17        False
# 3                   4          88         3135          8.31.17        False
# 4                   5          78          787          10.1.17         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018          6.24.17         True
# 19996           19997          41          127          11.9.17         True
# 19997           19998          87         2284          4.14.17         True
# 19998           19999           6         2764           7.3.17        False
# 19999           20000          11         1144          9.22.17         True
#
# ...

# %%
# %sql CREATE TABLE Transaction (transaction_id INTEGER, product_id INTEGER, customer_id INTEGER, transaction_date DATE, online_order BOOLEAN, order_status VARCHAR(100), brand VARCHAR(100), product_line VARCHAR(100), product_class VARCHAR(100), product_size VARCHAR(100), list_price NUMERIC(10, 2), standard_cost NUMERIC(10, 2));

# %sql COPY Transaction FROM '/content/transaction.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %sql SELECT * FROM Transaction;
# Out:
#  * postgresql+psycopg2://@/postgres
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
# %sql UPDATE Transaction SET customer_id = 3034 WHERE customer_id = 5034;

# %sql ALTER TABLE Customer ADD CONSTRAINT pk_customer_id PRIMARY KEY (customer_id);

# %sql ALTER TABLE Transaction ADD CONSTRAINT pk_transaction_id PRIMARY KEY (transaction_id);

# %sql ALTER TABLE Transaction ADD CONSTRAINT fk_customer_id FOREIGN KEY (customer_id) REFERENCES Customer(customer_id);
# Out:
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Вывести все уникальные бренды, у которых стандартная стоимость выше 1500 долларов:**

# %%
# %sql SELECT DISTINCT brand FROM Transaction WHERE standard_cost > 1500;
# Out:
#  * postgresql+psycopg2://@/postgres
#             brand
# 0      OHM Cycles
# 1   Trek Bicycles
# 2           Solex
# 3  Giant Bicycles

# %% [markdown]
# **Вывести все подтвержденные транзакции за период '2017-04-01' по '2017-04-09' включительно:**

# %%
# %sql SELECT * FROM Transaction WHERE order_status = 'Approved' AND transaction_date BETWEEN '2017-04-01' AND '2017-04-09'
# Out:
#  * postgresql+psycopg2://@/postgres
#      transaction_id  product_id  customer_id transaction_date online_order  \
# 0                17          79         2426       2017-04-03        False
# 1                19          54         2268       2017-04-06         True
# 2                23          37         2001       2017-04-08         True
# 3                83           0         3398       2017-04-01         True
# 4                89           0         2682       2017-04-04         True
# ..              ...         ...          ...              ...          ...
# 526           19655           0          336       2017-04-09         True
# 527           19853           7         3072       2017-04-02        False
# 528           19899          57          325       2017-04-06        False
# 529           19968           0         2751       2017-04-06        False
# 530           19988           0           13       2017-04-05         True
#
# ...

# %% [markdown]
# **Вывести все профессии у клиентов из сферы IT или Financial Services, которые начинаются с фразы 'Senior:**

# %%
# %sql SELECT job_title FROM Customer WHERE job_industry_category IN ('IT', 'Financial Services') AND job_title LIKE 'Senior%'
# Out:
#  * postgresql+psycopg2://@/postgres
#                    job_title
# 0    Senior Quality Engineer
# 1     Senior Cost Accountant
# 2   Senior Financial Analyst
# 3   Senior Financial Analyst
# 4     Senior Sales Associate
# ..                       ...
# 76   Senior Quality Engineer
# 77  Senior Financial Analyst
# 78  Senior Financial Analyst
# 79             Senior Editor
# 80  Senior Financial Analyst
#
# [81 rows x 1 columns]

# %% [markdown]
# **Вывести все бренды, которые закупают клиенты, работающие в сфере Financial Services:**

# %%
# %sql SELECT DISTINCT brand FROM Transaction WHERE customer_id IN (SELECT customer_id FROM Customer WHERE job_industry_category = 'Financial Services')
# Out:
#  * postgresql+psycopg2://@/postgres
#             brand
# 0            None
# 1   Trek Bicycles
# 2        WeareA2B
# 3           Solex
# 4  Giant Bicycles
# 5      OHM Cycles
# 6  Norco Bicycles

# %% [markdown]
# **Вывести 10 клиентов, которые оформили онлайн-заказ продукции из брендов 'Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles':**

# %%
# %sql SELECT c.* FROM Customer c JOIN Transaction t ON c.customer_id = t.customer_id WHERE t.online_order = true AND t.brand IN ('Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles') LIMIT 10
# Out:
#  * postgresql+psycopg2://@/postgres
#    customer_id first_name  last_name  gender         dob  \
# 0         3120     Lauree  O'Donnell  Female  1979-02-04
# 1          787      Norma     Batrim  Female  1996-12-15
# 2         2339     Damien  Haddeston    Male  1958-12-28
# 3         1243    Robbert     Blakey    Male  1953-08-09
# 4         3002     Tracey     Verdun    Male  1956-12-06
# 5         2666       Lyle      Eager    Male  1971-02-16
# 6         3368      Tanya     Boddis  Female  1967-07-17
# 7         2810     Malvin   Burchill    Male  1961-08-26
# 8         2003      Lilli     Hargey  Female  1962-06-21
# 9         2448      Lorri      Iston  Female  1992-12-18
#
#                       job_title job_industry_category     wealth_segment  \
# 0           Clinical Specialist                Health      Mass Customer
# 1                          None                Retail  Affluent Customer
# 2               Web Designer II              Property  Affluent Customer
# ...

# %% [markdown]
# **Вывести всех клиентов, у которых нет транзакций:**

# %%
# %sql SELECT c.* FROM Customer c LEFT JOIN Transaction t ON c.customer_id = t.customer_id WHERE t.customer_id IS NULL;
# Out:
#  * postgresql+psycopg2://@/postgres
#      customer_id first_name last_name  gender         dob  \
# 0            852      Andie    Bonney  Female  2000-11-04
# 1            869      Addia     Abels  Female  1984-03-11
# 2           1373   Shaylynn    Epsley  Female  1958-09-23
# 3           2074     Roslyn   Rawdall  Female  1997-06-11
# 4           2660       Hunt  Scollard    Male  1963-11-15
# ..           ...        ...       ...     ...         ...
# 502         3996    Rosalia  Halgarth  Female  1975-08-09
# 503         3997     Blanch    Nisuis  Female  2001-07-13
# 504         3998     Sarene   Woolley       U        None
# 505         3999  Patrizius      None    Male  1973-10-24
# 506         4000      Kippy   Oldland    Male  1991-11-05
#
#                     job_title job_industry_category     wealth_segment  \
# 0        Compensation Analyst    Financial Services  Affluent Customer
# 1    Account Representative I    Financial Services     High Net Worth
# ...

# %% [markdown]
# **Вывести всех клиентов из IT, у которых транзакции с максимальной стандартной стоимостью:**

# %%
# %sql SELECT c.* FROM Customer c JOIN Transaction t ON c.customer_id = t.customer_id WHERE c.job_industry_category = 'IT' AND t.standard_cost = (SELECT MAX(standard_cost) FROM Transaction WHERE customer_id = c.customer_id)
# Out:
#  * postgresql+psycopg2://@/postgres
#      customer_id first_name last_name  gender         dob  \
# 0           3406       Lucy  Lackmann  Female  1979-04-28
# 1           3473  Sanderson   Alloway       U        None
# 2             22    Deeanne  Durtnell  Female  1962-12-10
# 3           2487      Elton  Piggford    Male  1978-01-13
# 4           2426      Yancy     Ovett       U        None
# ..           ...        ...       ...     ...         ...
# 188         2084     Britni    Menguy  Female  1986-10-03
# 189          255     Keeley    Kruger  Female  1954-01-15
# 190          569      Jaime    Warkup    Male  1976-01-31
# 191         1210    Shandie    Sprigg       U        None
# 192          883     Lolita    Bennie       U        None
#
#                                 job_title job_industry_category  \
# 0    Business Systems Development Analyst                    IT
# 1           Analog Circuit Design manager                    IT
# ...

# %% [markdown]
# **Вывести всех клиентов из сферы IT и Health, у которых есть подтвержденные транзакции за период '2017-07-07' по '2017-07-17':**

# %%
# %sql SELECT c.* FROM Customer c JOIN Transaction t ON c.customer_id = t.customer_id WHERE c.job_industry_category IN ('IT', 'Health') AND t.order_status = 'Approved' AND t.transaction_date BETWEEN '2017-07-07' AND '2017-07-17'
# Out:
#  * postgresql+psycopg2://@/postgres
#      customer_id     first_name    last_name  gender         dob  \
# 0           2000           Kain         Rene       U        None
# 1           2337         Odilia         Bick  Female  2000-01-11
# 2            893          Gibby     Fearnley    Male  1983-09-11
# 3           3166        Bronson      Plowman    Male  1955-05-11
# 4           1555       Marcello     Spenclay    Male  1962-08-19
# ..           ...            ...          ...     ...         ...
# 119         1174  Shellysheldon  Gooderridge       U        None
# 120         1044      Frederico      Whilder       U        None
# 121         1862          Daron      Umpleby  Female  1980-06-29
# 122          712         Norine      Antonik  Female  1961-05-20
# 123         2442           Odie      Enrrico    Male  1957-10-13
#
#                  job_title job_industry_category     wealth_segment  \
# 0      Assistant Professor                    IT     High Net Worth
# ...
